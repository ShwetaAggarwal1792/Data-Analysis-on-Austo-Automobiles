# %%
import pandas as pd

# %%
df=pd.read_csv('austo_automobile .csv')

# %%
df.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
df.tail()
# Out:
#       Age Gender Profession Marital_status Education  No_of_Dependents  \
# 1576   22   Male   Salaried         Single  Graduate                 2
# 1577   22   Male   Business        Married  Graduate                 4
# 1578   22   Male   Business         Single  Graduate                 2
# 1579   22   Male   Business        Married  Graduate                 3
# 1580   22   Male   Salaried        Married  Graduate                 4
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 1576            No        Yes              No   33300             0.0
# 1577            No         No              No   32000             NaN
# 1578            No        Yes              No   32900             0.0
# 1579           Yes        Yes              No   32200             NaN
# 1580            No         No              No   31600             0.0
#
#       Total_salary  Price       Make
# 1576         33300  27000  Hatchback
# 1577         32000  31000  Hatchback
# ...

# %%
df.describe()
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000       1581.000000   1581.000000     1475.000000
# mean     31.922201          2.457938  60392.220114    20225.559322
# std       8.425978          0.943483  14674.825044    19573.149277
# min      22.000000          0.000000  30000.000000        0.000000
# 25%      25.000000          2.000000  51900.000000        0.000000
# 50%      29.000000          2.000000  59500.000000    25600.000000
# 75%      38.000000          3.000000  71800.000000    38300.000000
# max      54.000000          4.000000  99300.000000    80500.000000
#
#         Total_salary         Price
# count    1581.000000   1581.000000
# mean    79625.996205  35597.722960
# std     25545.857768  13633.636545
# min     30000.000000  18000.000000
# 25%     60500.000000  25000.000000
# 50%     78000.000000  31000.000000
# 75%     95900.000000  47000.000000
# max    171000.000000  70000.000000

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
df['Age']
# Out:
# 0       53
# 1       53
# 2       53
# 3       53
# 4       53
#         ..
# 1576    22
# 1577    22
# 1578    22
# 1579    22
# 1580    22
# Name: Age, Length: 1581, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Explore the salary distribution using histogram 
sns.histplot(data=df,x='Salary',kde=True,bins=20)
plt.title('Salary Distribution')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('austo_automobile .csv')
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Salary'] < lower_bound) | (df['Salary'] > upper_bound)]
print(f"Number of Salary outliers: {len(outliers)}")
# Out:
# Number of Salary outliers: 0

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1576    False
# 1577    False
# 1578    False
# 1579    False
# 1580    False
# Length: 1581, dtype: bool

# %%
#Explore the "Age" distribution using a histogram
sns.histplot(data=df,x='Age',kde=True,bins=20)
plt.title('Age Distribution')
plt.show()

# %%
#Explore the "Gender" distribution using a bar plot
plt.figure(figsize=(6,4))
sns.countplot(data=df,x='Gender',hue='Gender')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#Fixing spelling errors in 'gender'column
df['Gender']=df['Gender'].replace('Femal','Female')
df['Gender']=df['Gender'].replace('Femle','Female')

# %%
#Explore the "Gender" distribution using a bar plot
plt.figure(figsize=(6,4))
sns.countplot(data=df,x='Gender',hue='Gender')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#Explore the "Profession" distribution using a bar plot
plt.figure(figsize=(6,4))
sns.countplot(data=df,x='Profession',hue='Profession')
plt.title('Profession Distribution')
plt.xlabel('Profession')
plt.ylabel('Count')
plt.show()

# %%
#Explore the "Education" distribution using a bar plot
sns.countplot(data=df,x='Education',hue='Education')
plt.title('Education')
plt.xlabel('Education')
plt.ylabel('Count')
plt.show()

# %%
#Explore the "No of Dependents " distribution using a bar plot
sns.countplot(data=df,x="No_of_Dependents")
plt.title("No_of_Dependents Distribution")
plt.xlabel("No_Of_Dependents")
plt.show()

# %%
sns.countplot(data=df,x='Make',hue='Personal_loan')
plt.title('Personal Loan Distribution for each car type')
plt.xlabel('Car Type')
plt.show()

# %%
sns.countplot(data=df,x='Make')
plt.title('Make Distribution')
plt.xlabel('Make')
plt.show()

# %%
sns.histplot(data=df,x='Price',bins=20,kde=True)
plt.title('Price Distribution')
plt.show()

# %%
sns.histplot(data=df,x='Partner_salary',bins=20,kde=True)
plt.title('Partner_salary distribution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data=df,x='Total_salary',bins=20,kde=True)
plt.title('Total_salary')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(data=df,x='Total_salary')
plt.show()

# %%
sns.boxplot(data=df,x='Partner_salary')
plt.show()

# %%
sns.boxplot(data=df,x='No_of_Dependents')
plt.show()

# %%
#Visualize realationship between all numerical values
sns.pairplot(data=df[['Age','No_of_Dependents','Salary','Partner_salary','Total_salary','Price']])

# %%
#visualize the correlation matrix using a heatmap
corr_matrix=df[['Age','No_of_Dependents','Salary','Partner_salary','Total_salary','Price']].corr()
plot=sns.heatmap(data=corr_matrix,annot=True)

# %%
#Relationship between categorical vs numerical variables
sns.barplot(data=df,x='No_of_Dependents',y='Price')
plt.xlabel('No_of_Dependents')
plt.ylabel('Price')
plt.show()

# %%
sns.barplot(data=df,x='Personal_loan',y='Price')
plt.xlabel('Personal loan')
plt.ylabel('Price')
plt.show()

# %%
sns.barplot(data=df,x='House_loan',y='Price')
plt.xlabel('House loan')
plt.ylabel('Price')
plt.show()

# %%
sns.barplot(data=df,x='Total_salary',y='Make')
plt.xlabel('Total salary')
plt.ylabel('Make')
plt.show()

# %%
sns.barplot(data=df,x='House_loan',y='Price')
plt.xlabel('House_loan')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sns.countplot(data=df,x='House_loan',y='Price')
#       2 plt.xlabel('House_loan')
#       3 plt.ylabel('Price')
#
# NameError: name 'sns' is not defined

# %%
sns.barplot(data=df,x='Age',y='Make')
plt.xlabel('Age')
plt.ylabel('Make')
plt.show()

# %%
# bar plot to compare gender distribution for each car type
sns.countplot(data=df,x='Make',hue='Gender')
plt.title('Gender Distribution for Each Car Type')
plt.xlabel('Car Type')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # bar plot to compare gender distribution for each car type
# ----> 2 sns.countplot(data=df,x='Make',hue='Gender')
#       3 plt.title('Gender Distribution for Each Car Type')
#       4 plt.xlabel('Car Type')
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sns
sns.barplot(data=df,x='Gender',y='Price')
plt.xlabel('Gender')
plt.ylabel('Total spending')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 import seaborn as sns
# ----> 2 sns.barplot(data=df,x='Gender',y='Price')
#       3 plt.xlabel('Gender')
#       4 plt.ylabel('Total spending')
#
# NameError: name 'df' is not defined
